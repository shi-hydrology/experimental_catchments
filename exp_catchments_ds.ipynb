# %%
import pandas as pd

# %%
data = pd.read_csv("/home/julia/Документы/experimental_catchments/src/data/1_daily.csv")
data
# Out:
#      DATE_TIME  MEAN_DAILY_AIR_TEMP_CELSIUS  MAX_DAILY_AIR_TEMP_CELSIUS  \
# 0   1958-02-01                       -1.475                         0.7
# 1   1958-02-02                        0.075                         0.4
# 2   1958-02-03                       -0.100                         0.3
# 3   1958-02-04                       -4.050                        -0.1
# 4   1958-02-05                      -13.375                        -7.7
# 5   1958-02-06                      -13.500                       -11.2
# 6   1958-02-07                      -22.700                       -14.9
# 7   1958-02-08                      -16.375                       -13.4
# 8   1958-02-09                      -20.725                       -15.1
# 9   1958-02-10                      -18.900                       -16.1
# 10  1958-02-11                      -22.950                       -15.4
# 11  1958-02-12                      -12.450                       -10.0
# ...

# %%
dict_data={}
for header in data.columns.values.tolist():
    dict_data[header]=data[header].tolist()
dict_data
# Out:
# {'DATE_TIME': ['1958-02-01',
#   '1958-02-02',
#   '1958-02-03',
#   '1958-02-04',
#   '1958-02-05',
#   '1958-02-06',
#   '1958-02-07',
#   '1958-02-08',
#   '1958-02-09',
#   '1958-02-10',
#   '1958-02-11',
#   '1958-02-12',
#   '1958-02-13',
#   '1958-02-14',
#   '1958-02-15',
#   '1958-02-16',
#   '1958-02-17',
#   '1958-02-18',
#   '1958-02-19',
#   '1958-02-20',
#   '1958-02-21',
#   '1958-02-22',
#   '1958-02-23',
#   '1958-02-24',
#   '1958-02-25',
#   '1958-02-26',
#   '1958-02-27',
#   '1958-02-28'],
#  'MEAN_DAILY_AIR_TEMP_CELSIUS': [-1.475,
#   0.07500000000000001,
#   -0.1,
#   -4.050000000000002,
#   -13.375,
#   -13.500000000000002,
#   -22.700000000000006,
#   -16.375,
#   -20.725,
#   -18.9,
#   -22.950000000000006,
#   -12.45,
#   -8.525,
#   -5.875,
#   -0.75,
#   -1.65,
#   -4.525,
#   -8.75,
#   -8.200000000000001,
#   -7.05,
#   -9.575,
#   -8.625,
#   -14.025,
#   -13.175,
#   -15.0,
#   -18.35,
#   -3.1250000000000004,
#   -5.2],
# ...

# %%
import json
jsn=json.dumps(dict_data)
jsn
# Out:
# '{"DATE_TIME": ["1958-02-01", "1958-02-02", "1958-02-03", "1958-02-04", "1958-02-05", "1958-02-06", "1958-02-07", "1958-02-08", "1958-02-09", "1958-02-10", "1958-02-11", "1958-02-12", "1958-02-13", "1958-02-14", "1958-02-15", "1958-02-16", "1958-02-17", "1958-02-18", "1958-02-19", "1958-02-20", "1958-02-21", "1958-02-22", "1958-02-23", "1958-02-24", "1958-02-25", "1958-02-26", "1958-02-27", "1958-02-28"], "MEAN_DAILY_AIR_TEMP_CELSIUS": [-1.475, 0.07500000000000001, -0.1, -4.050000000000002, -13.375, -13.500000000000002, -22.700000000000006, -16.375, -20.725, -18.9, -22.950000000000006, -12.45, -8.525, -5.875, -0.75, -1.65, -4.525, -8.75, -8.200000000000001, -7.05, -9.575, -8.625, -14.025, -13.175, -15.0, -18.35, -3.1250000000000004, -5.2], "MAX_DAILY_AIR_TEMP_CELSIUS": [0.7, 0.4, 0.3, -0.1, -7.7, -11.2, -14.9, -13.4, -15.1, -16.1, -15.4, -10.0, -6.8, -3.0, 0.1, -0.1, -2.1, -7.6, -6.1, -5.1, -7.5, -6.2, -9.1, -10.1, -9.7, -8.1, 0.3, 0.4], "MIN_DAILY_AIR_TEMP_CELSIUS": [-6.4, -0.7, -0.
# ...

# %%
with open('./daily.json', 'w') as file:
    file.write(jsn)

# %%
import matplotlib.pyplot as plt



plt.plot()
